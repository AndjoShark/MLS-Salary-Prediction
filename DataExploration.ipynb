# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('modelingdf.csv')
df = df.drop('Unnamed: 0', axis = 1)

# %%
df.head()
# Out:
#      A    FC    G    GP    GS    MINS   OFF    R  SHTS   SOG    Y  season  \
# 0  0.0   7.0  0.0   8.0   5.0   460.0   3.0  0.0   8.0   3.0  0.0    2007
# 1  4.0  28.0  3.0  30.0  11.0  1241.0   4.0  0.0  38.0  16.0  5.0    2007
# 2  2.0  21.0  8.0  33.0  28.0  2181.0  37.0  0.0  65.0  41.0  3.0    2007
# 3  3.0  15.0  8.0  22.0  21.0  1721.0   5.0  0.0  44.0  22.0  1.0    2007
# 4  0.0  43.0  1.0  26.0  24.0  2044.0   2.0  0.0  11.0   3.0  4.0    2007
#
#   club position  next_year_compensation            name  current_compensation
# 0  CLB        M                   12900   brian plotkin                 30000
# 1  CHI        F                   63100      calen carr                 50500
# 2  TFC        F                   61273    chad barrett                 48713
# 3  CHI        F                   86075     chris rolfe                 74700
# 4  CHI        D                   44625  dasan robinson                 42500

# %%
heatmap = df.drop(['name', 'club', 'position'], axis = 1)
corr = heatmap.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, annot=True, cmap='RdBu_r', linewidth = .5, mask = mask)

# %%
sns.barplot(x = 'season', y='next_year_compensation', data=df)
plt.pyplot.xticks(rotation=70)
plt.pyplot.show()

# %%
sns.swarmplot(x='season', y = 'next_year_compensation', data=df)
plt.pyplot.xticks(rotation=70)
plt.pyplot.show()

# %%
sns.boxplot(x='season', y='next_year_compensation', data = df)
plt.pyplot.xticks(rotation=70)
plt.pyplot.show()

# %%
sns.boxplot(x='season', y='next_year_compensation', data = df)
plt.pyplot.xticks(rotation=70)
plt.pyplot.ylim(0, 1000000)
plt.pyplot.show()

# %%
sns.barplot(x = 'position', y='next_year_compensation', data=df)
plt.pyplot.show()

# %%
sns.boxplot(y='next_year_compensation', data = df)
plt.pyplot.show()

# %%
sns.boxplot(y='next_year_compensation', data = df)
plt.pyplot.ylim(0, 500000)
plt.pyplot.show()

# %%
sns.lmplot(x='MINS', y='next_year_compensation', data=df)

# %%
sns.lmplot(x='GS', y='next_year_compensation', data=df, scatter_kws={'alpha':0.4})

# %%
sns.lmplot(x='G', y='next_year_compensation', data=df, scatter_kws={'alpha':0.4})

# %%
sns.lmplot(x='A', y='next_year_compensation', data=df, scatter_kws={'alpha':0.4})

# %%
sns.lmplot(x='SOG', y='next_year_compensation', data=df)

# %%
sns.lmplot(x='Y', y='next_year_compensation', data=df, scatter_kws={'alpha':0.4})

# %%
sns.lmplot(x='R', y='next_year_compensation', data=df, scatter_kws={'alpha':0.4})

# %%
sns.palplot()
